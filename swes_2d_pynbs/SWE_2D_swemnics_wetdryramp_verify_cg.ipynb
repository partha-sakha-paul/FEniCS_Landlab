# %%
# Define the inflow and outflow computation
def compute_flux(h, ux, uy):
    n = FacetNormal(domain)  # Normal vector on the cell faces    
    q = ufl.as_vector([h * ux, h * uy])  # Discharge vector
    flux_integrand = dot(q, n)  # Integrand for flux computation
    exterior_facet_measure = Measure("exterior_facet", domain=domain)
    # print('flux_integrand', flux_integrand)
    # print('n', n)
    # print('q', q)
    # print('qx',q[0].x.array)
    # print('qy',q[1].x.array)
    # print('exterior_facet_measure', exterior_facet_measure)
    
    # Assemble the flux integrand over all facets
    flux_integral = assemble_scalar(form(flux_integrand * exterior_facet_measure))
    # print(f"Flux integral over all facets: {flux_integral}")
    
    # Define inflow and outflow integrals
    inflow_form = ufl.conditional(flux_integrand < 0, -flux_integrand, 0) * exterior_facet_measure # conditional: If q.n < 0(inflow), take −q.n; otherwise, take 0.
    outflow_form = ufl.conditional(flux_integrand > 0, flux_integrand, 0) * exterior_facet_measure # conditional: If q.n > 0(outflow), take q.n; otherwise, take 0.   
    inflow = assemble_scalar(form(inflow_form))
    outflow = assemble_scalar(form(outflow_form))
    return inflow, outflow

# %%
# Calculate mass conservation residual for each node/cell
def mass_conservation_residual(h, ux, uy, h_prev, ux_prev, uy_prev, dx, dy, dt, maps):
    # Extract values using the maps
    h_values = h.x.array[maps[0]]
    ux_values = ux.x.array[maps[1]]
    uy_values = uy.x.array[maps[2]]
    h_prev_values = h_prev.x.array[maps[0]]
    ux_prev_values = ux_prev.x.array[maps[1]]
    uy_prev_values = uy_prev.x.array[maps[2]]
    
    # Initialize residual array
    residual = np.zeros_like(h_values)
    
    # Time derivative term for h
    residual += (h_values - h_prev_values) / dt
    
    # Spatial derivatives for qx and qy (using finite differences)
    residual += np.gradient(h_values * ux_values, dx)  # the derivative method for qx
    residual += np.gradient(h_values * uy_values, dy)  # the derivative method for qy
    
    return residual

# %%
# necessary importments
import numpy as np
from mpi4py import MPI
from dolfinx import mesh, fem, nls, io
from dolfinx.fem.petsc import NonlinearProblem
from dolfinx.nls.petsc import NewtonSolver
from dolfinx.fem import locate_dofs_geometrical
from petsc4py.PETSc import ScalarType
from ufl import TrialFunction, TestFunction, div, dx
from ufl.finiteelement import FiniteElement, MixedElement
import ufl
import basix
from dolfinx.plot import vtk_mesh
import pyvista as pv
import os
import matplotlib.pyplot as plt
from ufl import inner, dx
from dolfinx.fem import assemble_scalar, form  # to verify conservation law
from ufl import dot, FacetNormal, Measure  # to verify conservation law
from dolfinx.mesh import exterior_facet_indices # to verify conservation law

# Create a directory to store frames
os.makedirs("frames", exist_ok=True)

# mesh and domain creation
Lx, Ly = 13800.0, 7200.0  
nx, ny = 12, 6           
domain = mesh.create_rectangle(
    MPI.COMM_WORLD, 
    [np.array([0.0, 0.0]), np.array([Lx, Ly])], 
    [nx, ny], 
    cell_type=mesh.CellType.triangle
)
domain.topology.create_connectivity(domain.topology.dim - 1, domain.topology.dim)
domain.topology.create_connectivity(0, 1)  # Connectivity between vertices and cells

# parameters and constants
g = 9.81  
mannings = 0.02
t, dt, T = 0.0, 600, 7*24*3600.0
num_steps = int(T / dt)

# element and functionspace
element = basix.ufl.mixed_element([basix.ufl.element("CG", str(domain.ufl_cell()), 1)] * 3)
V = fem.functionspace(domain, element)
num_subs = V.num_sub_spaces

# exporting spaces and mappings to use later
spaces = []
maps = []
for i in range(num_subs):
    space_i, map_i = V.sub(i).collapse()
    spaces.append(space_i)
    maps.append(map_i)

# required current time step functions
W = fem.Function(V)  
h, ux, uy = W.split()

# creating bathymetry
V0, _ = V.sub(0).collapse()  
z = fem.Function(V0) 
z.interpolate(lambda x: 5.0 / 13800 * (13800 - x[0]))
x = domain.geometry.x
# Update the third column (z-coordinate) of the mesh geometry
x[:, 2] = z.x.array

# initializing h, ux, uy with all zeros as water is flat and still at time t = 0 
h.interpolate(lambda x: np.full_like(x[0], 0.0))
ux.interpolate(lambda x: np.full_like(x[0], 0.0))
uy.interpolate(lambda x: np.full_like(x[0], 0.0))

# required previous time step functions
W_prev = fem.Function(V)  
h_prev, ux_prev, uy_prev = W_prev.split()

# initializing h_prev, ux_prev, uy_prev with all zeros as water is flat and still at time t = 0 so previous also will be same as an asumption
h_prev.interpolate(lambda x: np.full_like(x[0], 0.0))
ux_prev.interpolate(lambda x: np.full_like(x[0], 0.0))
uy_prev.interpolate(lambda x: np.full_like(x[0], 0.0))

# wetting-drying correction due to unstable solutions in the dry area
wd_alpha = 0.36
wd_alpha_sq = ScalarType(wd_alpha**2)
def wd_correction(h, alpha_sq):
    """Compute correction to water column height for wetting-and-drying."""
    return 0.5 * (ufl.sqrt(h**2 + alpha_sq) - h)

# creating trial and test functions for the weak formulation
U = TrialFunction(V)
V_test = TestFunction(V)

# The Weak Form:
'''
# old one from De Almeida Paper:
def weak_form(U, U_prev, V_test, wd=True):
    h, ux, uy = U
    h_prev, ux_prev, uy_prev = U_prev
    v_h, v_ux, v_uy = V_test
    print("Symbolic h before wd:", h)
    if wd:
        h_corrected = h + wd_correction(h, wd_alpha_sq)
    else:
        h_corrected = h
    print("Symbolic h after wd:", h_corrected)
    continuity = (h - h_prev) / dt * v_h * dx + \
                 (((h+z) * ux).dx(0) * v_h + ((h+z) * uy).dx(1) * v_h) * dx
    momentum_x = (ux - ux_prev) / dt * v_ux * dx + \
                 g * (h+z) * (h+z).dx(0) * v_ux * dx - \
                 g * h * z.dx(0) * v_ux * dx + \
                 g * mannings**2 * ((abs(ux) * ux) / h_corrected**(1/3)) * v_ux * dx
    momentum_y = (uy - uy_prev) / dt * v_uy * dx + \
                 g * (h+z) * (h+z).dx(1) * v_uy * dx - \
                 g * h * z.dx(1) * v_uy * dx + \
                 g * mannings**2 * ((abs(uy) * uy) / h_corrected**(1/3)) * v_uy * dx
    return continuity + momentum_x + momentum_y
'''
# weak form new one from swemnics paper
def weak_form(U, U_prev, V_test, wd=True):
    h, ux, uy = U
    h_prev, ux_prev, uy_prev = U_prev
    v_h, v_ux, v_uy = V_test
    print("Symbolic h before wd:", h)
    if wd:
        h_corrected = h + wd_correction(h, wd_alpha_sq)
    else:
        h_corrected = h
    print("Symbolic h after wd:", h_corrected)
    continuity = (h - h_prev) / dt * v_h * dx + \
                 (((h+z) * ux).dx(0) * v_h + ((h+z) * uy).dx(1) * v_h) * dx
    
    momentum_x = ((h+z)*ux - (h_prev+z)*ux_prev) / dt * v_ux * dx + \
                 ((h+z)*ux**2 + 0.5*g*h*(h+2*z)).dx(0) * v_ux * dx + ((h+z)*ux*uy).dx(1) * v_ux * dx - \
                 g * h * z.dx(0) * v_ux * dx + \
                 g * mannings**2 * ((abs(ux) * ux) / h_corrected**(1/3)) * v_ux * dx
    
    momentum_y = ((h+z)*uy - (h_prev+z)*uy_prev) / dt * v_uy * dx + \
                 ((h+z)*uy**2 + 0.5*g*h*(h+2*z)).dx(1) * v_uy * dx + ((h+z)*ux*uy).dx(0) * v_uy * dx - \
                 g * h * z.dx(1) * v_uy * dx + \
                 g * mannings**2 * ((abs(uy) * uy) / h_corrected**(1/3)) * v_uy * dx
    return continuity + momentum_x + momentum_y

# getting spaces for bcs
V0, _ = V.sub(0).collapse()
V1, _ = V.sub(1).collapse()
V2, _ = V.sub(2).collapse()

# open(left) and wall(other) boundaries
def open_boundary(x):
    return np.isclose(x[0], 0)
def wall_boundary(x):
    return np.logical_not(np.isclose(x[0], 0)) | np.isclose(x[1], 0) | np.isclose(x[1], Ly)

# Locate boundary facets
boundary_facets_open = mesh.locate_entities_boundary(domain, domain.topology.dim - 1, open_boundary)
boundary_facets_wall = mesh.locate_entities_boundary(domain, domain.topology.dim - 1, wall_boundary)

# initialization of tidal value for the tide on the left(open) boundary
tidal_value = fem.Constant(domain, ScalarType(0.0))

# function for updating the tidal value dynamically in the time loop at each time
def update_tidal_value(t):
    tidal_value.value = (
        np.tanh(2.0 * t / (86400.0 * 2.0)) * 2.0 * np.cos(t * (2.0 * np.pi / (12.0 * 60 * 60)) - (90 * np.pi / 180))
    )
# Initialize tidal_value at t=0
update_tidal_value(t=0.0)

# creating dirichlet bcs for the wall and open boundaries
sub_dofs_h_left = fem.locate_dofs_topological(V.sub(0), domain.topology.dim - 1, boundary_facets_open)
bc_h_left = fem.dirichletbc(tidal_value, sub_dofs_h_left, V.sub(0))
sub_dofs_ux_others = fem.locate_dofs_topological(V.sub(1), domain.topology.dim - 1, boundary_facets_wall)
sub_dofs_uy_others = fem.locate_dofs_topological(V.sub(2), domain.topology.dim - 1, boundary_facets_wall)
bc_ux_others = fem.dirichletbc(fem.Constant(domain, ScalarType(0.0)), sub_dofs_ux_others, V.sub(1))
bc_uy_others = fem.dirichletbc(fem.Constant(domain, ScalarType(0.0)), sub_dofs_uy_others, V.sub(2))
bcs = [bc_h_left, bc_ux_others, bc_uy_others]

# NonlinearProblem and the NewtonSolver set up with wd = True and bcs
problem = NonlinearProblem(weak_form(W, W_prev, V_test, wd=True), W, bcs=bcs)
solver = NewtonSolver(MPI.COMM_WORLD, problem)
solver.rtol = 1e-6 
solver.atol = 1e-6  
solver.max_it = 50
solver.error_on_nonconvergence = True

# Extract cells, cell types, and points from the domain mesh using VTK utilities
cells, cell_types, points = vtk_mesh(domain)
# Create a PyVista UnstructuredGrid from the mesh data
pv_mesh = pv.UnstructuredGrid(cells, cell_types, points)
# Initialize a PyVista plotter for visualization
plotter = pv.Plotter()
# desired time steps to visualize
desired_steps = [i for i in range(0, 9000000)]
# list to store the time steps
time_steps = []

# coordinates for observation stations on the mesh (x, y positions)
station_coords = [(9000, 3650), (11000, 3650), (13500, 3650)]
# dictionary to store the nearest mesh point indices for each station
stations = {coord: None for coord in station_coords}

# nearest mesh point to each station based on Euclidean distance
for coord in station_coords:
    x_coord, y_coord = coord  # x and y coordinates of the station
    distances = np.sqrt((x[:, 0] - x_coord)**2 + (x[:, 1] - y_coord)**2)  # Calculate distances to all mesh points
    station_idx = np.argmin(distances)  # index of the closest mesh point
    stations[coord] = station_idx  # Store the index in the dictionary

# Print the indices of the nearest mesh points for each station
# print("Nearest points in the mesh for each station:", stations)

# Initialize a dictionary to store time-series data (time, h, ux, uy) for each station
time_series_data = {coord: {"time": [], "h": [], "ux": [], "uy": []} for coord in station_coords}

# Loop over all time steps
for step in range(num_steps + 1):
    t = step * dt  # Compute the current time
    time_steps.append(t)  # Store the time step
    update_tidal_value(t=t)  # Update tidal boundary values

    # If the current step is in the desired steps, prepare for visualization
    if step in desired_steps:
        # Calculate the residual for mass conservation
        residual = mass_conservation_residual(h, ux, uy, h_prev, ux_prev, uy_prev, Lx / nx, Ly / ny, dt, maps)
        # print(residual.shape)
        # print or plot the residual for each step
        print(f"Step {step}, Mass Conservation Residual: {np.linalg.norm(residual)}")
        plotter.clear()  # Clear the plotter for the next step
        
        # Compute inflow and outflow for the current solution
        inflow, outflow = compute_flux(h, ux, uy)
        # Log results
        print(f"Time step {step}, Time {t:.2f} s")
        print(f"Inflow rate: {inflow:.6f}, Outflow rate: {outflow:.6f}")
        print(f"Net flux (should be close to zero): {inflow - outflow:.6f}")
        
        # Extract values for bed elevation, water depth, and velocities
        z_values = z.x.array
        h_values = h.x.array[maps[0]]
        ux_values = ux.x.array[maps[1]]
        uy_values = uy.x.array[maps[2]]

        # Add scalar data to the PyVista mesh for visualization
        pv_mesh.point_data["Bed Elevation (z)"] = z_values
        pv_mesh.point_data["Water Depth (h)"] = h_values
        pv_mesh.point_data["Bed Elevation (z) + Water Depth (h)"] = z_values + h_values
        pv_mesh.point_data["Discharge (qx)"] = h_values * ux_values  # Compute discharge in x direction
        pv_mesh.point_data["Discharge (qy)"] = h_values * uy_values  # Compute discharge in y direction

        # Start a virtual frame buffer for rendering
        pv.start_xvfb()

        # Warp the mesh by bed elevation for a 3D effect
        warped = pv_mesh.warp_by_scalar("Bed Elevation (z)")

        # Add the warped mesh to the plotter with water depth as the color map
        plotter.add_mesh(
            warped,
            scalars="Bed Elevation (z) + Water Depth (h)",
            cmap="viridis",
            show_edges=True,
            show_scalar_bar=True,
            scalar_bar_args={"title": "Water Depth (h)"}
        )

        # Create velocity arrows for visualization
        arrow_magnitude = 0.5  # Scale factor for arrows
        arrows = np.column_stack((ux_values, uy_values, np.zeros_like(ux_values))) * arrow_magnitude

        # Add a time label to the plot
        # plotter.add_text(f"Time: {t}s", position="upper_left", font_size=12)
        plotter.add_text(
            f"Inflow: {inflow:.6f}\nOutflow: {outflow:.6f}\nNet flux: {inflow - outflow:.6f}", 
            position="lower_left", font_size=8)
        plotter.add_text(f"Step: {step}, Time: {t:.2f}s\nMass Conservation Residual: {np.linalg.norm(residual)}", font_size=8)

        # show the plot        
        # plotter.show()

        # Save the current frame as an image
        filename = f"frames/frame_{step:04d}.png"
        plotter.screenshot(filename)
        
        # Clear the plotter for the next frame (to avoid overwriting elements)
        plotter.clear()

    # Store time-series data for each station
    for coord, idx in stations.items():
        time_series_data[coord]["time"].append(t)
        time_series_data[coord]["h"].append(h.x.array[maps[0]][idx])  # Water depth at station
        time_series_data[coord]["ux"].append(ux.x.array[maps[1]][idx])  # x-velocity at station
        time_series_data[coord]["uy"].append(uy.x.array[maps[2]][idx])  # y-velocity at station

    # Solve the system for the current time step
    solver.solve(W)

    # Scatter the solution vector (updates distributed arrays in parallel computation)
    W.x.scatter_forward()

    # Update previous step variables for the next iteration
    h_prev.x.array[:] = h.x.array[:]
    ux_prev.x.array[:] = ux.x.array[:]
    uy_prev.x.array[:] = uy.x.array[:]
# Out:
# [188 190 205 217 226 232]
# 1
# FunctionSpace(<Mesh #0>, Basix element (P, triangle, 1, gll_warped, unset, False, float64, []))
# sho [207 210 228 243 255 264 270]
# Symbolic h before wd: f[0]
# Symbolic h after wd: f[0] + 0.5 * (-1 * f[0] + sqrt(0.1296 + f[0] ** 2))
# 2025-01-28 08:41:51.289 (   2.211s) [    7FF360442140]vtkXOpenGLRenderWindow.:1290  WARN| vtkXOpenGLRenderWindow (0x522a250): bad X server connection. DISPLAY=
# 2025-01-28 08:41:51.340 (   2.262s) [    7FF360442140]vtkXOpenGLRenderWindow.:1290  WARN| vtkXOpenGLRenderWindow (0x6e17ad0): bad X server connection. DISPLAY=
# Step 0, Mass Conservation Residual: 0.0
# Time step 0, Time 0.00 s
# Inflow rate: 0.000000, Outflow rate: 0.000000
# Net flux (should be close to zero): 0.000000
# Step 1, Mass Conservation Residual: 0.0
# Time step 1, Time 600.00 s
# Inflow rate: 0.000000, Outflow rate: 0.000000
# Net flux (should be close to zero): 0.000000
# Step 2, Mass Conservation Residual: 2.8461252484294037e-09
# Time step 2, Time 1200.00 s
# Inflow rate: 0.012701, Outflow rate: 0.000000
# Net flux (should be close to zero): 0.012701
# Step 3, Mass Conservation Residual: 4.552085722800334e-08
# Time step 3, Time 1800.00 s
# Inflow rate: 0.198245, Outflow rate: 0.000000
# Net flux (should be close to zero): 0.198245
# Step 4, Mass Conservation Residual: 2.3317806447245303e-07
# Time step 4, Time 2400.00 s
# Inflow rate: 0.962297, Outflow rate: 0.000000
# Net flux (should be close to zero): 0.962297
# Step 5, Mass Conservation Residual: 7.496358202100907e-07
# Time step 5, Time 3000.00 s
# Inflow rate: 2.872205, Outflow rate: 0.000000
# Net flux (should be close to zero): 2.872205
# Step 6, Mass Conservation Residual: 1.8580584567935995e-06
# Time step 6, Time 3600.00 s
# Inflow rate: 6.529191, Outflow rate: 0.000000
# Net flux (should be close to zero): 6.529191
# Step 7, Mass Conservation Residual: 3.873685513893553e-06
# Time step 7, Time 4200.00 s
# Inflow rate: 12.422892, Outflow rate: 0.000000
# Net flux (should be close to zero): 12.422892
# Step 8, Mass Conservation Residual: 7.098751543223617e-06
# Time step 8, Time 4800.00 s
# Inflow rate: 20.800166, Outflow rate: 0.000000
# Net flux (should be close to zero): 20.800166
# Step 9, Mass Conservation Residual: 1.1737112325586777e-05
# Time step 9, Time 5400.00 s
# Inflow rate: 31.587064, Outflow rate: 0.000000
# Net flux (should be close to zero): 31.587064
# Step 10, Mass Conservation Residual: 1.7836560201929838e-05
# Time step 10, Time 6000.00 s
# Inflow rate: 44.386519, Outflow rate: 0.000000
# Net flux (should be close to zero): 44.386519
# Step 11, Mass Conservation Residual: 2.5288451738546847e-05
# Time step 11, Time 6600.00 s
# Inflow rate: 58.543171, Outflow rate: 0.000000
# Net flux (should be close to zero): 58.543171
# Step 12, Mass Conservation Residual: 3.38656342406773e-05
# Time step 12, Time 7200.00 s
# Inflow rate: 73.241910, Outflow rate: 0.000000
# Net flux (should be close to zero): 73.241910
# Step 13, Mass Conservation Residual: 4.326276828582349e-05
# Time step 13, Time 7800.00 s
# Inflow rate: 87.603457, Outflow rate: 0.000000
# Net flux (should be close to zero): 87.603457
# Step 14, Mass Conservation Residual: 5.311958225485626e-05
# Time step 14, Time 8400.00 s
# Inflow rate: 100.755076, Outflow rate: 0.000000
# Net flux (should be close to zero): 100.755076
# Step 15, Mass Conservation Residual: 6.302736535924072e-05
# Time step 15, Time 9000.00 s
# Inflow rate: 111.873438, Outflow rate: 0.000000
# Net flux (should be close to zero): 111.873438
# Step 16, Mass Conservation Residual: 7.252910566342629e-05
# Time step 16, Time 9600.00 s
# Inflow rate: 120.208680, Outflow rate: 0.000000
# Net flux (should be close to zero): 120.208680
# Step 17, Mass Conservation Residual: 8.11243711793845e-05
# Time step 17, Time 10200.00 s
# Inflow rate: 125.100619, Outflow rate: 0.000000
# Net flux (should be close to zero): 125.100619
# Step 18, Mass Conservation Residual: 8.82837946808656e-05
# Time step 18, Time 10800.00 s
# Inflow rate: 125.994792, Outflow rate: 0.000000
# Net flux (should be close to zero): 125.994792
# Step 19, Mass Conservation Residual: 9.347734534973214e-05
# Time step 19, Time 11400.00 s
# Inflow rate: 122.461315, Outflow rate: 0.000000
# Net flux (should be close to zero): 122.461315
# Step 20, Mass Conservation Residual: 9.621528935750372e-05
# Time step 20, Time 12000.00 s
# Inflow rate: 114.216230, Outflow rate: 0.000000
# Net flux (should be close to zero): 114.216230
# Step 21, Mass Conservation Residual: 9.609799672213716e-05
# Time step 21, Time 12600.00 s
# Inflow rate: 101.144046, Outflow rate: 0.000000
# Net flux (should be close to zero): 101.144046
# Step 22, Mass Conservation Residual: 9.287509524830356e-05
# Time step 22, Time 13200.00 s
# Inflow rate: 83.320144, Outflow rate: 0.000000
# Net flux (should be close to zero): 83.320144
# Step 23, Mass Conservation Residual: 8.65216025996232e-05
# Time step 23, Time 13800.00 s
# Inflow rate: 63.668251, Outflow rate: 2.635961
# Net flux (should be close to zero): 61.032290
# Step 24, Mass Conservation Residual: 7.735149258448732e-05
# Time step 24, Time 14400.00 s
# Inflow rate: 44.306489, Outflow rate: 9.495320
# Net flux (should be close to zero): 34.811170
# Step 25, Mass Conservation Residual: 6.621186376058761e-05
# Time step 25, Time 15000.00 s
# Inflow rate: 24.734092, Outflow rate: 19.249199
# Net flux (should be close to zero): 5.484892
# Step 26, Mass Conservation Residual: 5.490525294919671e-05
# Time step 26, Time 15600.00 s
# Inflow rate: 5.307223, Outflow rate: 31.036194
# Net flux (should be close to zero): -25.728971
# Step 27, Mass Conservation Residual: 4.705789021437932e-05
# Time step 27, Time 16200.00 s
# Inflow rate: 0.000000, Outflow rate: 56.870721
# Net flux (should be close to zero): -56.870721
# Step 28, Mass Conservation Residual: 4.768140760054312e-05
# Time step 28, Time 16800.00 s
# Inflow rate: 0.000000, Outflow rate: 85.322068
# Net flux (should be close to zero): -85.322068
# Step 29, Mass Conservation Residual: 5.650964970732474e-05
# Time step 29, Time 17400.00 s
# Inflow rate: 0.000000, Outflow rate: 108.659024
# Net flux (should be close to zero): -108.659024
# Step 30, Mass Conservation Residual: 6.717390230869613e-05
# Time step 30, Time 18000.00 s
# Inflow rate: 0.000000, Outflow rate: 124.962038
# Net flux (should be close to zero): -124.962038
# Step 31, Mass Conservation Residual: 7.505839873215859e-05
# Time step 31, Time 18600.00 s
# Inflow rate: 0.000000, Outflow rate: 133.053999
# Net flux (should be close to zero): -133.053999
# Step 32, Mass Conservation Residual: 7.845589954789217e-05
# Time step 32, Time 19200.00 s
# Inflow rate: 0.000000, Outflow rate: 132.452317
# Net flux (should be close to zero): -132.452317
# Step 33, Mass Conservation Residual: 7.711357890008513e-05
# Time step 33, Time 19800.00 s
# Inflow rate: 0.000000, Outflow rate: 123.109876
# Net flux (should be close to zero): -123.109876
# Step 34, Mass Conservation Residual: 7.137530652788356e-05
# Time step 34, Time 20400.00 s
# Inflow rate: 0.000000, Outflow rate: 105.126918
# Net flux (should be close to zero): -105.126918
# Step 35, Mass Conservation Residual: 6.183919890619047e-05
# Time step 35, Time 21000.00 s
# Inflow rate: 0.000000, Outflow rate: 78.578196
# Net flux (should be close to zero): -78.578196
# Step 36, Mass Conservation Residual: 4.941382393180816e-05
# Time step 36, Time 21600.00 s
# Inflow rate: 0.000000, Outflow rate: 43.500250
# Net flux (should be close to zero): -43.500250
# Step 37, Mass Conservation Residual: 3.61480575922989e-05
# Time step 37, Time 22200.00 s
# Inflow rate: 0.000000, Outflow rate: 0.000000
# Net flux (should be close to zero): -0.000000
# Step 38, Mass Conservation Residual: 2.8552665145039467e-05
# Time step 38, Time 22800.00 s
# Inflow rate: 51.595466, Outflow rate: 0.000000
# Net flux (should be close to zero): 51.595466
# Step 39, Mass Conservation Residual: 3.714768731136955e-05
# Time step 39, Time 23400.00 s
# Inflow rate: 110.622022, Outflow rate: 0.000000
# Net flux (should be close to zero): 110.622022
# Step 40, Mass Conservation Residual: 5.8281301520794674e-05
# Time step 40, Time 24000.00 s
# Inflow rate: 176.032296, Outflow rate: 0.000000
# Net flux (should be close to zero): 176.032296
# Step 41, Mass Conservation Residual: 8.487165887602325e-05
# Time step 41, Time 24600.00 s
# Inflow rate: 246.417261, Outflow rate: 0.000000
# Net flux (should be close to zero): 246.417261
# Step 42, Mass Conservation Residual: 0.00011417812839443396
# Time step 42, Time 25200.00 s
# Inflow rate: 320.067993, Outflow rate: 0.000000
# Net flux (should be close to zero): 320.067993
# Step 43, Mass Conservation Residual: 0.0001449105723966581
# Time step 43, Time 25800.00 s
# Inflow rate: 395.047224, Outflow rate: 0.000000
# Net flux (should be close to zero): 395.047224
# Step 44, Mass Conservation Residual: 0.00017616472610437238
# Time step 44, Time 26400.00 s
# Inflow rate: 469.252720, Outflow rate: 0.000000
# Net flux (should be close to zero): 469.252720
# Step 45, Mass Conservation Residual: 0.00020716025943444207
# Time step 45, Time 27000.00 s
# Inflow rate: 540.469608, Outflow rate: 0.000000
# Net flux (should be close to zero): 540.469608
# Step 46, Mass Conservation Residual: 0.000237167257320584
# Time step 46, Time 27600.00 s
# Inflow rate: 606.417554, Outflow rate: 0.000000
# Net flux (should be close to zero): 606.417554
# Step 47, Mass Conservation Residual: 0.0002654849766268399
# Time step 47, Time 28200.00 s
# Inflow rate: 664.800081, Outflow rate: 0.000000
# Net flux (should be close to zero): 664.800081
# Step 48, Mass Conservation Residual: 0.0002914393273807784
# Time step 48, Time 28800.00 s
# Inflow rate: 713.360632, Outflow rate: 0.000000
# Net flux (should be close to zero): 713.360632
# Step 49, Mass Conservation Residual: 0.00031438883246096645
# Time step 49, Time 29400.00 s
# Inflow rate: 749.946119, Outflow rate: 0.000000
# Net flux (should be close to zero): 749.946119
# Step 50, Mass Conservation Residual: 0.00033373501110331953
# Time step 50, Time 30000.00 s
# Inflow rate: 772.575685, Outflow rate: 0.000000
# Net flux (should be close to zero): 772.575685
# Step 51, Mass Conservation Residual: 0.00034893451712213457
# Time step 51, Time 30600.00 s
# Inflow rate: 779.511165, Outflow rate: 0.000000
# Net flux (should be close to zero): 779.511165
# Step 52, Mass Conservation Residual: 0.0003595115823863072
# Time step 52, Time 31200.00 s
# Inflow rate: 769.325396, Outflow rate: 0.000000
# Net flux (should be close to zero): 769.325396
# Step 53, Mass Conservation Residual: 0.00036507208762311474
# Time step 53, Time 31800.00 s
# Inflow rate: 740.963956, Outflow rate: 0.000000
# Net flux (should be close to zero): 740.963956
# Step 54, Mass Conservation Residual: 0.0003653227119944656
# Time step 54, Time 32400.00 s
# Inflow rate: 693.795185, Outflow rate: 0.000000
# Net flux (should be close to zero): 693.795185
# Step 55, Mass Conservation Residual: 0.00036010027120837756
# Time step 55, Time 33000.00 s
# Inflow rate: 627.642539, Outflow rate: 0.000000
# Net flux (should be close to zero): 627.642539
# Step 56, Mass Conservation Residual: 0.00034942071457236913
# Time step 56, Time 33600.00 s
# Inflow rate: 542.790927, Outflow rate: 0.000000
# Net flux (should be close to zero): 542.790927
# Step 57, Mass Conservation Residual: 0.0003335701136619047
# Time step 57, Time 34200.00 s
# Inflow rate: 439.953733, Outflow rate: 0.000000
# Net flux (should be close to zero): 439.953733
# Step 58, Mass Conservation Residual: 0.000313295065887144
# Time step 58, Time 34800.00 s
# Inflow rate: 320.176076, Outflow rate: 0.000000
# Net flux (should be close to zero): 320.176076
# Step 59, Mass Conservation Residual: 0.0002902361436554464
# Time step 59, Time 35400.00 s
# Inflow rate: 184.614682, Outflow rate: 0.000000
# Net flux (should be close to zero): 184.614682
# Step 60, Mass Conservation Residual: 0.0002680081219176855
# Time step 60, Time 36000.00 s
# Inflow rate: 60.664159, Outflow rate: 26.090598
# Net flux (should be close to zero): 34.573561
# Step 61, Mass Conservation Residual: 0.00025331037052505093
# Time step 61, Time 36600.00 s
# Inflow rate: 0.000000, Outflow rate: 125.025323
# Net flux (should be close to zero): -125.025323
# Step 62, Mass Conservation Residual: 0.0002524309283166154
# Time step 62, Time 37200.00 s
# Inflow rate: 0.000000, Outflow rate: 277.868286
# Net flux (should be close to zero): -277.868286
# Step 63, Mass Conservation Residual: 0.00026483454743037006
# Time step 63, Time 37800.00 s
# Inflow rate: 0.000000, Outflow rate: 407.724226
# Net flux (should be close to zero): -407.724226
# Step 64, Mass Conservation Residual: 0.0002827633425381216
# Time step 64, Time 38400.00 s
# Inflow rate: 0.000000, Outflow rate: 504.063730
# Net flux (should be close to zero): -504.063730
# Step 65, Mass Conservation Residual: 0.0002982896791660822
# Time step 65, Time 39000.00 s
# Inflow rate: 0.000000, Outflow rate: 562.369307
# Net flux (should be close to zero): -562.369307
# Step 66, Mass Conservation Residual: 0.000306002098739913
# Time step 66, Time 39600.00 s
# Inflow rate: 0.000000, Outflow rate: 583.819613
# Net flux (should be close to zero): -583.819613
# Step 67, Mass Conservation Residual: 0.0003070696698535243
# Time step 67, Time 40200.00 s
# Inflow rate: 0.000000, Outflow rate: 573.202461
# Net flux (should be close to zero): -573.202461
# Step 68, Mass Conservation Residual: 0.00030400157089708447
# Time step 68, Time 40800.00 s
# Inflow rate: 0.000000, Outflow rate: 535.787203
# Net flux (should be close to zero): -535.787203
# Step 69, Mass Conservation Residual: 0.0002948193780444987
# Time step 69, Time 41400.00 s
# Inflow rate: 0.000000, Outflow rate: 474.782519
# Net flux (should be close to zero): -474.782519
# Step 70, Mass Conservation Residual: 0.0002774684028740242
# Time step 70, Time 42000.00 s
# Inflow rate: 0.000000, Outflow rate: 391.067778
# Net flux (should be close to zero): -391.067778
# Step 71, Mass Conservation Residual: 0.0002519699137054466
# Time step 71, Time 42600.00 s
# Inflow rate: 0.000000, Outflow rate: 284.321118
# Net flux (should be close to zero): -284.321118
# Step 72, Mass Conservation Residual: 0.00021807546054304408
# Time step 72, Time 43200.00 s
# Inflow rate: 0.000000, Outflow rate: 154.030604
# Net flux (should be close to zero): -154.030604
# Step 73, Mass Conservation Residual: 0.0001832182315015255
# Time step 73, Time 43800.00 s
# Inflow rate: 0.000000, Outflow rate: 0.000000
# Net flux (should be close to zero): -0.000000
# Step 74, Mass Conservation Residual: 0.0001667913153751871
# Time step 74, Time 44400.00 s
# Inflow rate: 177.431527, Outflow rate: 0.000000
# Net flux (should be close to zero): 177.431527
# Step 75, Mass Conservation Residual: 0.00017891153800366706
# Time step 75, Time 45000.00 s
# Inflow rate: 377.186397, Outflow rate: 0.000000
# Net flux (should be close to zero): 377.186397
# Step 76, Mass Conservation Residual: 0.0002300673337733242
# Time step 76, Time 45600.00 s
# Inflow rate: 597.102334, Outflow rate: 0.000000
# Net flux (should be close to zero): 597.102334
# Step 77, Mass Conservation Residual: 0.0003166469161390326
# Time step 77, Time 46200.00 s
# Inflow rate: 833.370168, Outflow rate: 0.000000
# Net flux (should be close to zero): 833.370168
# Step 78, Mass Conservation Residual: 0.0004312754111372023
# Time step 78, Time 46800.00 s
# Inflow rate: 1079.491131, Outflow rate: 0.000000
# Net flux (should be close to zero): 1079.491131
# Step 79, Mass Conservation Residual: 0.0005679536186246355
# Time step 79, Time 47400.00 s
# Inflow rate: 1324.679129, Outflow rate: 0.000000
# Net flux (should be close to zero): 1324.679129
# Step 80, Mass Conservation Residual: 0.0007214121336500459
# Time step 80, Time 48000.00 s
# Inflow rate: 1552.677913, Outflow rate: 0.000000
# Net flux (should be close to zero): 1552.677913
# Step 81, Mass Conservation Residual: 0.0008864306787703531
# Time step 81, Time 48600.00 s
# Inflow rate: 1744.349753, Outflow rate: 0.000000
# Net flux (should be close to zero): 1744.349753
# Step 82, Mass Conservation Residual: 0.0010529308511040508
# Time step 82, Time 49200.00 s
# Inflow rate: 1883.568190, Outflow rate: 0.000000
# Net flux (should be close to zero): 1883.568190
# Step 83, Mass Conservation Residual: 0.0012084666963630304
# Time step 83, Time 49800.00 s
# Inflow rate: 1962.688107, Outflow rate: 0.000000
# Net flux (should be close to zero): 1962.688107
# Step 84, Mass Conservation Residual: 0.0013454303048599328
# Time step 84, Time 50400.00 s
# Inflow rate: 1983.438403, Outflow rate: 0.000000
# Net flux (should be close to zero): 1983.438403
# Step 85, Mass Conservation Residual: 0.001466501242127926
# Time step 85, Time 51000.00 s
# Inflow rate: 1952.511224, Outflow rate: 0.000000
# Net flux (should be close to zero): 1952.511224
# Step 86, Mass Conservation Residual: 0.0015774775242598973
# Time step 86, Time 51600.00 s
# Inflow rate: 1882.653620, Outflow rate: 6.921827
# Net flux (should be close to zero): 1875.731793
# Step 87, Mass Conservation Residual: 0.0016778644228604006
# Time step 87, Time 52200.00 s
# Inflow rate: 1785.659280, Outflow rate: 30.684647
# Net flux (should be close to zero): 1754.974632
# Step 88, Mass Conservation Residual: 0.0017606501631340678
# Time step 88, Time 52800.00 s
# Inflow rate: 1651.563976, Outflow rate: 62.282815
# Net flux (should be close to zero): 1589.281161
# Step 89, Mass Conservation Residual: 0.0018160867430402372
# Time step 89, Time 53400.00 s
# Inflow rate: 1562.134980, Outflow rate: 183.736786
# Net flux (should be close to zero): 1378.398195
# Step 90, Mass Conservation Residual: 0.001833638390259774
# Time step 90, Time 54000.00 s
# Inflow rate: 1505.156148, Outflow rate: 378.322896
# Net flux (should be close to zero): 1126.833252
# Step 91, Mass Conservation Residual: 0.0018027321011793243
# Time step 91, Time 54600.00 s
# Inflow rate: 1398.647524, Outflow rate: 556.886253
# Net flux (should be close to zero): 841.761270
# Step 92, Mass Conservation Residual: 0.0017157010927911006
# Time step 92, Time 55200.00 s
# Inflow rate: 1260.214059, Outflow rate: 729.187173
# Net flux (should be close to zero): 531.026886
# Step 93, Mass Conservation Residual: 0.0015729172148165
# Time step 93, Time 55800.00 s
# Inflow rate: 1066.835758, Outflow rate: 863.411614
# Net flux (should be close to zero): 203.424144
# Step 94, Mass Conservation Residual: 0.0013894402032016671
# Time step 94, Time 56400.00 s
# Inflow rate: 847.489396, Outflow rate: 978.818972
# Net flux (should be close to zero): -131.329576
# Step 95, Mass Conservation Residual: 0.001198689650507445
# Time step 95, Time 57000.00 s
# Inflow rate: 597.551168, Outflow rate: 1057.814268
# Net flux (should be close to zero): -460.263099
# Step 96, Mass Conservation Residual: 0.0010452636853395252
# Time step 96, Time 57600.00 s
# Inflow rate: 367.973284, Outflow rate: 1130.171396
# Net flux (should be close to zero): -762.198112
# Step 97, Mass Conservation Residual: 0.0009532626214517551
# Time step 97, Time 58200.00 s
# Inflow rate: 163.627732, Outflow rate: 1178.640374
# Net flux (should be close to zero): -1015.012642
# Step 98, Mass Conservation Residual: 0.0009070928780629836
# Time step 98, Time 58800.00 s
# Inflow rate: 68.040269, Outflow rate: 1274.587450
# Net flux (should be close to zero): -1206.547181
# Step 99, Mass Conservation Residual: 0.0008750995957892441
# Time step 99, Time 59400.00 s
# Inflow rate: 34.791307, Outflow rate: 1370.525303
# Net flux (should be close to zero): -1335.733996
# Step 100, Mass Conservation Residual: 0.0008373453317608173
# Time step 100, Time 60000.00 s
# Inflow rate: 1.937128, Outflow rate: 1410.187722
# Net flux (should be close to zero): -1408.250594
# Step 101, Mass Conservation Residual: 0.0007902086658886764
# Time step 101, Time 60600.00 s
# Inflow rate: 0.000000, Outflow rate: 1429.714226
# Net flux (should be close to zero): -1429.714226
# Step 102, Mass Conservation Residual: 0.0007372034748798266
# Time step 102, Time 61200.00 s
# Inflow rate: 0.000000, Outflow rate: 1403.182824
# Net flux (should be close to zero): -1403.182824
# Step 103, Mass Conservation Residual: 0.0006811512156019038
# Time step 103, Time 61800.00 s
# Inflow rate: 0.000000, Outflow rate: 1329.752381
# Net flux (should be close to zero): -1329.752381
# Step 104, Mass Conservation Residual: 0.0006218881510613256
# Time step 104, Time 62400.00 s
# Inflow rate: 0.000000, Outflow rate: 1209.759399
# Net flux (should be close to zero): -1209.759399
# Step 105, Mass Conservation Residual: 0.0005574745377429269
# Time step 105, Time 63000.00 s
# Inflow rate: 0.000000, Outflow rate: 1044.026929
# Net flux (should be close to zero): -1044.026929
# Step 106, Mass Conservation Residual: 0.00048626034726298033
# Time step 106, Time 63600.00 s
# Inflow rate: 0.000000, Outflow rate: 834.813889
# Net flux (should be close to zero): -834.813889
# Step 107, Mass Conservation Residual: 0.0004085413468954047
# Time step 107, Time 64200.00 s
# Inflow rate: 0.000000, Outflow rate: 586.391104
# Net flux (should be close to zero): -586.391104
# Step 108, Mass Conservation Residual: 0.0003280033282190208
# Time step 108, Time 64800.00 s
# Inflow rate: 0.000000, Outflow rate: 305.281367
# Net flux (should be close to zero): -305.281367
# Step 109, Mass Conservation Residual: 0.0002542829011052311
# Time step 109, Time 65400.00 s
# Inflow rate: 0.000000, Outflow rate: 0.000000
# Net flux (should be close to zero): -0.000000
# Step 110, Mass Conservation Residual: 0.0002079554218517133
# Time step 110, Time 66000.00 s
# Inflow rate: 320.131045, Outflow rate: 0.000000
# Net flux (should be close to zero): 320.131045
# Step 111, Mass Conservation Residual: 0.000215155054031183
# Time step 111, Time 66600.00 s
# Inflow rate: 646.851770, Outflow rate: 0.000000
# Net flux (should be close to zero): 646.851770
# Step 112, Mass Conservation Residual: 0.00027300933910227436
# Time step 112, Time 67200.00 s
# Inflow rate: 973.900991, Outflow rate: 0.000000
# Net flux (should be close to zero): 973.900991
# Step 113, Mass Conservation Residual: 0.000356440927214962
# Time step 113, Time 67800.00 s
# Inflow rate: 1296.291197, Outflow rate: 0.000000
# Net flux (should be close to zero): 1296.291197
# Step 114, Mass Conservation Residual: 0.0004491389187750768
# Time step 114, Time 68400.00 s
# Inflow rate: 1609.089216, Outflow rate: 0.000000
# Net flux (should be close to zero): 1609.089216
# Step 115, Mass Conservation Residual: 0.0005435227269389944
# Time step 115, Time 69000.00 s
# Inflow rate: 1906.726003, Outflow rate: 0.000000
# Net flux (should be close to zero): 1906.726003
# Step 116, Mass Conservation Residual: 0.0006355788561953767
# Time step 116, Time 69600.00 s
# Inflow rate: 2182.932464, Outflow rate: 0.000000
# Net flux (should be close to zero): 2182.932464
# Step 117, Mass Conservation Residual: 0.0007226549550369498
# Time step 117, Time 70200.00 s
# Inflow rate: 2431.017942, Outflow rate: 0.000000
# Net flux (should be close to zero): 2431.017942
# Step 118, Mass Conservation Residual: 0.0008026998693782659
# Time step 118, Time 70800.00 s
# Inflow rate: 2644.244928, Outflow rate: 0.000000
# Net flux (should be close to zero): 2644.244928
# Step 119, Mass Conservation Residual: 0.0008740123700949472
# Time step 119, Time 71400.00 s
# Inflow rate: 2816.180640, Outflow rate: 0.000000
# Net flux (should be close to zero): 2816.180640
# Step 120, Mass Conservation Residual: 0.0009351655715822508
# Time step 120, Time 72000.00 s
# Inflow rate: 2940.993465, Outflow rate: 0.000000
# Net flux (should be close to zero): 2940.993465
# Step 121, Mass Conservation Residual: 0.0009849920938303752
# Time step 121, Time 72600.00 s
# Inflow rate: 3013.698737, Outflow rate: 0.000000
# Net flux (should be close to zero): 3013.698737
# Step 122, Mass Conservation Residual: 0.001022588893547334
# Time step 122, Time 73200.00 s
# Inflow rate: 3030.364571, Outflow rate: 0.000000
# Net flux (should be close to zero): 3030.364571
# Step 123, Mass Conservation Residual: 0.0010473261546598246
# Time step 123, Time 73800.00 s
# Inflow rate: 2988.282397, Outflow rate: 0.000000
# Net flux (should be close to zero): 2988.282397
# Step 124, Mass Conservation Residual: 0.0010588546871376347
# Time step 124, Time 74400.00 s
# Inflow rate: 2886.098949, Outflow rate: 0.000000
# Net flux (should be close to zero): 2886.098949
# Step 125, Mass Conservation Residual: 0.0010571108155287441
# Time step 125, Time 75000.00 s
# Inflow rate: 2723.899100, Outflow rate: 0.000000
# Net flux (should be close to zero): 2723.899100
# Step 126, Mass Conservation Residual: 0.0010423202945262244
# Time step 126, Time 75600.00 s
# Inflow rate: 2503.223325, Outflow rate: 0.000000
# Net flux (should be close to zero): 2503.223325
# Step 127, Mass Conservation Residual: 0.0010150080431502852
# Time step 127, Time 76200.00 s
# Inflow rate: 2226.997104, Outflow rate: 0.000000
# Net flux (should be close to zero): 2226.997104
# Step 128, Mass Conservation Residual: 0.0009760304015572955
# Time step 128, Time 76800.00 s
# Inflow rate: 1899.338197, Outflow rate: 0.000000
# Net flux (should be close to zero): 1899.338197
# Step 129, Mass Conservation Residual: 0.0009266769945287532
# Time step 129, Time 77400.00 s
# Inflow rate: 1525.186121, Outflow rate: 0.000000
# Net flux (should be close to zero): 1525.186121
# Step 130, Mass Conservation Residual: 0.0008689462079368778
# Time step 130, Time 78000.00 s
# Inflow rate: 1109.603466, Outflow rate: 0.000000
# Net flux (should be close to zero): 1109.603466
# Step 131, Mass Conservation Residual: 0.0008063496423677298
# Time step 131, Time 78600.00 s
# Inflow rate: 660.387866, Outflow rate: 4.047744
# Net flux (should be close to zero): 656.340122
# Step 132, Mass Conservation Residual: 0.0007470790613414802
# Time step 132, Time 79200.00 s
# Inflow rate: 270.239540, Outflow rate: 101.106576
# Net flux (should be close to zero): 169.132964
# Step 133, Mass Conservation Residual: 0.0007050953997226396
# Time step 133, Time 79800.00 s
# Inflow rate: 0.000000, Outflow rate: 335.447058
# Net flux (should be close to zero): -335.447058
# Step 134, Mass Conservation Residual: 0.0006859097576216254
# Time step 134, Time 80400.00 s
# Inflow rate: 0.000000, Outflow rate: 800.311100
# Net flux (should be close to zero): -800.311100
# Step 135, Mass Conservation Residual: 0.0006844296390111502
# Time step 135, Time 81000.00 s
# Inflow rate: 0.000000, Outflow rate: 1168.168993
# Net flux (should be close to zero): -1168.168993
# Step 136, Mass Conservation Residual: 0.0006961027070391339
# Time step 136, Time 81600.00 s
# Inflow rate: 0.000000, Outflow rate: 1420.450140
# Net flux (should be close to zero): -1420.450140
# Step 137, Mass Conservation Residual: 0.0007117756296718933
# Time step 137, Time 82200.00 s
# Inflow rate: 0.000000, Outflow rate: 1556.316147
# Net flux (should be close to zero): -1556.316147
# Step 138, Mass Conservation Residual: 0.0007183828303291856
# Time step 138, Time 82800.00 s
# Inflow rate: 0.000000, Outflow rate: 1591.974769
# Net flux (should be close to zero): -1591.974769
# Step 139, Mass Conservation Residual: 0.0007166206814192215
# Time step 139, Time 83400.00 s
# Inflow rate: 0.000000, Outflow rate: 1550.454392
# Net flux (should be close to zero): -1550.454392
# Step 140, Mass Conservation Residual: 0.0007109725644608376
# Time step 140, Time 84000.00 s
# Inflow rate: 0.000000, Outflow rate: 1447.580950
# Net flux (should be close to zero): -1447.580950
# Step 141, Mass Conservation Residual: 0.0006786989439502423
# Time step 141, Time 84600.00 s
# Inflow rate: 0.000000, Outflow rate: 1285.466480
# Net flux (should be close to zero): -1285.466480
# Step 142, Mass Conservation Residual: 0.0006407796338324543
# Time step 142, Time 85200.00 s
# Inflow rate: 0.000000, Outflow rate: 1059.226529
# Net flux (should be close to zero): -1059.226529
# Step 143, Mass Conservation Residual: 0.0006039443862848074
# Time step 143, Time 85800.00 s
# Inflow rate: 0.000000, Outflow rate: 766.879482
# Net flux (should be close to zero): -766.879482
# Step 144, Mass Conservation Residual: 0.0005516533350177014
# Time step 144, Time 86400.00 s
# Inflow rate: 0.000000, Outflow rate: 411.608872
# Net flux (should be close to zero): -411.608872
# Step 145, Mass Conservation Residual: 0.00048618769535072986
# Time step 145, Time 87000.00 s
# Inflow rate: 0.000000, Outflow rate: 0.000000
# Net flux (should be close to zero): -0.000000
# Step 146, Mass Conservation Residual: 0.00044670764269187755
# Time step 146, Time 87600.00 s
# Inflow rate: 458.212208, Outflow rate: 0.000000
# Net flux (should be close to zero): 458.212208
# Step 147, Mass Conservation Residual: 0.0004937235477839434
# Time step 147, Time 88200.00 s
# Inflow rate: 948.509945, Outflow rate: 0.000000
# Net flux (should be close to zero): 948.509945
# Step 148, Mass Conservation Residual: 0.0006276074970905826
# Time step 148, Time 88800.00 s
# Inflow rate: 1452.272313, Outflow rate: 0.000000
# Net flux (should be close to zero): 1452.272313
# Step 149, Mass Conservation Residual: 0.0008305444515682972
# Time step 149, Time 89400.00 s
# Inflow rate: 1952.746086, Outflow rate: 0.000000
# Net flux (should be close to zero): 1952.746086
# Step 150, Mass Conservation Residual: 0.0010899085673799183
# Time step 150, Time 90000.00 s
# Inflow rate: 2444.096725, Outflow rate: 0.000000
# Net flux (should be close to zero): 2444.096725
# Step 151, Mass Conservation Residual: 0.0014138278979306908
# Time step 151, Time 90600.00 s
# Inflow rate: 2936.225845, Outflow rate: 0.000000
# Net flux (should be close to zero): 2936.225845
# Step 152, Mass Conservation Residual: 0.0018130862168135966
# Time step 152, Time 91200.00 s
# Inflow rate: 3439.965710, Outflow rate: 0.000000
# Net flux (should be close to zero): 3439.965710
# Step 153, Mass Conservation Residual: 0.0023140918152627977
# Time step 153, Time 91800.00 s
# Inflow rate: 3934.312344, Outflow rate: 0.000000
# Net flux (should be close to zero): 3934.312344
# Step 154, Mass Conservation Residual: 0.002967853128571562
# Time step 154, Time 92400.00 s
# Inflow rate: 4383.960194, Outflow rate: 34.342401
# Net flux (should be close to zero): 4349.617793
# Step 155, Mass Conservation Residual: 0.003749978112629681
# Time step 155, Time 93000.00 s
# Inflow rate: 4721.897512, Outflow rate: 113.193172
# Net flux (should be close to zero): 4608.704339
# Step 156, Mass Conservation Residual: 0.004467430700975379
# Time step 156, Time 93600.00 s
# Inflow rate: 4860.882203, Outflow rate: 183.998365
# Net flux (should be close to zero): 4676.883838
# Step 157, Mass Conservation Residual: 0.004909831167717024
# Time step 157, Time 94200.00 s
# Inflow rate: 5182.389632, Outflow rate: 609.767231
# Net flux (should be close to zero): 4572.622401
# Step 158, Mass Conservation Residual: 0.005020068139465255
# Time step 158, Time 94800.00 s
# Inflow rate: 5274.497679, Outflow rate: 942.226209
# Net flux (should be close to zero): 4332.271471
# Step 159, Mass Conservation Residual: 0.004875829506490713
# Time step 159, Time 95400.00 s
# Inflow rate: 5212.555076, Outflow rate: 1243.728550
# Net flux (should be close to zero): 3968.826526
# Step 160, Mass Conservation Residual: 0.004596673210576459
# Time step 160, Time 96000.00 s
# Inflow rate: 4923.706023, Outflow rate: 1445.953922
# Net flux (should be close to zero): 3477.752101
# Step 161, Mass Conservation Residual: 0.004292347404597278
# Time step 161, Time 96600.00 s
# Inflow rate: 4421.397881, Outflow rate: 1566.348475
# Net flux (should be close to zero): 2855.049407
# Step 162, Mass Conservation Residual: 0.004055421090788741
# Time step 162, Time 97200.00 s
# Inflow rate: 3727.931810, Outflow rate: 1610.270229
# Net flux (should be close to zero): 2117.661581
# Step 163, Mass Conservation Residual: 0.003954375212527413
# Time step 163, Time 97800.00 s
# Inflow rate: 2895.629945, Outflow rate: 1583.695596
# Net flux (should be close to zero): 1311.934349
# Step 164, Mass Conservation Residual: 0.0039775725179924835
# Time step 164, Time 98400.00 s
# Inflow rate: 2313.896373, Outflow rate: 1806.831480
# Net flux (should be close to zero): 507.064893
# Step 165, Mass Conservation Residual: 0.003980594976445237
# Time step 165, Time 99000.00 s
# Inflow rate: 2114.788536, Outflow rate: 2359.771088
# Net flux (should be close to zero): -244.982552
# Step 166, Mass Conservation Residual: 0.003851236985748575
# Time step 166, Time 99600.00 s
# Inflow rate: 1878.376846, Outflow rate: 2813.344504
# Net flux (should be close to zero): -934.967658
# Step 167, Mass Conservation Residual: 0.0035904922318219855
# Time step 167, Time 100200.00 s
# Inflow rate: 1558.439477, Outflow rate: 3098.408746
# Net flux (should be close to zero): -1539.969269
# Step 168, Mass Conservation Residual: 0.003249864934617021
# Time step 168, Time 100800.00 s
# Inflow rate: 1215.875171, Outflow rate: 3240.505646
# Net flux (should be close to zero): -2024.630475
# Step 169, Mass Conservation Residual: 0.0028821800577916393
# Time step 169, Time 101400.00 s
# Inflow rate: 882.720966, Outflow rate: 3257.556368
# Net flux (should be close to zero): -2374.835402
# Step 170, Mass Conservation Residual: 0.0025238929590708013
# Time step 170, Time 102000.00 s
# Inflow rate: 576.979367, Outflow rate: 3181.189549
# Net flux (should be close to zero): -2604.210182
# Step 171, Mass Conservation Residual: 0.0021944980865833495
# Time step 171, Time 102600.00 s
# Inflow rate: 304.574007, Outflow rate: 3041.630604
# Net flux (should be close to zero): -2737.056597
# Step 172, Mass Conservation Residual: 0.0019044378053192173
# Time step 172, Time 103200.00 s
# Inflow rate: 70.430628, Outflow rate: 2861.382167
# Net flux (should be close to zero): -2790.951539
# Step 173, Mass Conservation Residual: 0.0016595088705586576
# Time step 173, Time 103800.00 s
# Inflow rate: 0.000000, Outflow rate: 2771.132190
# Net flux (should be close to zero): -2771.132190
# Step 174, Mass Conservation Residual: 0.00145985856618412
# Time step 174, Time 104400.00 s
# Inflow rate: 0.000000, Outflow rate: 2674.009673
# Net flux (should be close to zero): -2674.009673
# Step 175, Mass Conservation Residual: 0.0012951405169402065
# Time step 175, Time 105000.00 s
# Inflow rate: 0.000000, Outflow rate: 2496.930462
# Net flux (should be close to zero): -2496.930462
# Step 176, Mass Conservation Residual: 0.0011492749545588554
# Time step 176, Time 105600.00 s
# Inflow rate: 0.000000, Outflow rate: 2240.714494
# Net flux (should be close to zero): -2240.714494
# Step 177, Mass Conservation Residual: 0.0010085981200090336
# Time step 177, Time 106200.00 s
# Inflow rate: 0.000000, Outflow rate: 1908.767720
# Net flux (should be close to zero): -1908.767720
# Step 178, Mass Conservation Residual: 0.0008655092837274381
# Time step 178, Time 106800.00 s
# Inflow rate: 0.000000, Outflow rate: 1507.300227
# Net flux (should be close to zero): -1507.300227
# Step 179, Mass Conservation Residual: 0.0007190871347271939
# Time step 179, Time 107400.00 s
# Inflow rate: 0.000000, Outflow rate: 1045.796083
# Net flux (should be close to zero): -1045.796083
# Step 180, Mass Conservation Residual: 0.0005754800367732196
# Time step 180, Time 108000.00 s
# Inflow rate: 0.000000, Outflow rate: 537.588369
# Net flux (should be close to zero): -537.588369
# Step 181, Mass Conservation Residual: 0.0004502450405865114
# Time step 181, Time 108600.00 s
# Inflow rate: 0.000000, Outflow rate: 0.000000
# Net flux (should be close to zero): -0.000000
# Step 182, Mass Conservation Residual: 0.00037231819013653435
# Time step 182, Time 109200.00 s
# Inflow rate: 548.436346, Outflow rate: 0.000000
# Net flux (should be close to zero): 548.436346
# Step 183, Mass Conservation Residual: 0.0003733376833613954
# Time step 183, Time 109800.00 s
# Inflow rate: 1094.055296, Outflow rate: 0.000000
# Net flux (should be close to zero): 1094.055296
# Step 184, Mass Conservation Residual: 0.0004483220052843032
# Time step 184, Time 110400.00 s
# Inflow rate: 1629.707042, Outflow rate: 0.000000
# Net flux (should be close to zero): 1629.707042
# Step 185, Mass Conservation Residual: 0.000563315712651373
# Time step 185, Time 111000.00 s
# Inflow rate: 2150.566093, Outflow rate: 0.000000
# Net flux (should be close to zero): 2150.566093
# Step 186, Mass Conservation Residual: 0.0006935427042797703
# Time step 186, Time 111600.00 s
# Inflow rate: 2650.619074, Outflow rate: 0.000000
# Net flux (should be close to zero): 2650.619074
# Step 187, Mass Conservation Residual: 0.000826556656254752
# Time step 187, Time 112200.00 s
# Inflow rate: 3121.838169, Outflow rate: 0.000000
# Net flux (should be close to zero): 3121.838169
# Step 188, Mass Conservation Residual: 0.0009556699241082177
# Time step 188, Time 112800.00 s
# Inflow rate: 3554.761458, Outflow rate: 0.000000
# Net flux (should be close to zero): 3554.761458
# Step 189, Mass Conservation Residual: 0.0010765845913879091
# Time step 189, Time 113400.00 s
# Inflow rate: 3939.348751, Outflow rate: 0.000000
# Net flux (should be close to zero): 3939.348751
# Step 190, Mass Conservation Residual: 0.0011861408529954328
# Time step 190, Time 114000.00 s
# Inflow rate: 4265.692584, Outflow rate: 0.000000
# Net flux (should be close to zero): 4265.692584
# Step 191, Mass Conservation Residual: 0.0012818730682975612
# Time step 191, Time 114600.00 s
# Inflow rate: 4524.541257, Outflow rate: 0.000000
# Net flux (should be close to zero): 4524.541257
# Step 192, Mass Conservation Residual: 0.0013618519652474263
# Time step 192, Time 115200.00 s
# Inflow rate: 4707.696228, Outflow rate: 0.000000
# Net flux (should be close to zero): 4707.696228
# Step 193, Mass Conservation Residual: 0.0014246302089557616
# Time step 193, Time 115800.00 s
# Inflow rate: 4808.341904, Outflow rate: 0.000000
# Net flux (should be close to zero): 4808.341904
# Step 194, Mass Conservation Residual: 0.0014692263581907556
# Time step 194, Time 116400.00 s
# Inflow rate: 4821.337761, Outflow rate: 0.000000
# Net flux (should be close to zero): 4821.337761
# Step 195, Mass Conservation Residual: 0.00149512158223319
# Time step 195, Time 117000.00 s
# Inflow rate: 4743.479432, Outflow rate: 0.000000
# Net flux (should be close to zero): 4743.479432
# Step 196, Mass Conservation Residual: 0.0015022576952137686
# Time step 196, Time 117600.00 s
# Inflow rate: 4573.719187, Outflow rate: 0.000000
# Net flux (should be close to zero): 4573.719187
# Step 197, Mass Conservation Residual: 0.0014910312962844016
# Time step 197, Time 118200.00 s
# Inflow rate: 4313.322694, Outflow rate: 0.000000
# Net flux (should be close to zero): 4313.322694
# Step 198, Mass Conservation Residual: 0.001462284487586847
# Time step 198, Time 118800.00 s
# Inflow rate: 3965.925041, Outflow rate: 0.000000
# Net flux (should be close to zero): 3965.925041
# Step 199, Mass Conservation Residual: 0.0014172970893026216
# Time step 199, Time 119400.00 s
# Inflow rate: 3537.434892, Outflow rate: 0.000000
# Net flux (should be close to zero): 3537.434892
# Step 200, Mass Conservation Residual: 0.001357800234526663
# Time step 200, Time 120000.00 s
# Inflow rate: 3035.713741, Outflow rate: 0.000000
# Net flux (should be close to zero): 3035.713741
# Step 201, Mass Conservation Residual: 0.0012860496438858618
# Time step 201, Time 120600.00 s
# Inflow rate: 2469.930933, Outflow rate: 0.000000
# Net flux (should be close to zero): 2469.930933
# Step 202, Mass Conservation Residual: 0.0012050685331262848
# Time step 202, Time 121200.00 s
# Inflow rate: 1849.437727, Outflow rate: 0.000000
# Net flux (should be close to zero): 1849.437727
# Step 203, Mass Conservation Residual: 0.0011193071146586202
# Time step 203, Time 121800.00 s
# Inflow rate: 1181.596435, Outflow rate: 0.000000
# Net flux (should be close to zero): 1181.596435
# Step 204, Mass Conservation Residual: 0.0010376944252174474
# Time step 204, Time 122400.00 s
# Inflow rate: 582.867543, Outflow rate: 112.195685
# Net flux (should be close to zero): 470.671858
# Step 205, Mass Conservation Residual: 0.0009777858441101196
# Time step 205, Time 123000.00 s
# Inflow rate: 58.069994, Outflow rate: 321.438338
# Net flux (should be close to zero): -263.368344
# Step 206, Mass Conservation Residual: 0.0009445646313428196
# Time step 206, Time 123600.00 s
# Inflow rate: 0.000000, Outflow rate: 961.941383
# Net flux (should be close to zero): -961.941383
# Step 207, Mass Conservation Residual: 0.0009265907544744889
# Time step 207, Time 124200.00 s
# Inflow rate: 0.000000, Outflow rate: 1519.454120
# Net flux (should be close to zero): -1519.454120
# Step 208, Mass Conservation Residual: 0.0009218313982399736
# Time step 208, Time 124800.00 s
# Inflow rate: 0.000000, Outflow rate: 1893.621215
# Net flux (should be close to zero): -1893.621215
# Step 209, Mass Conservation Residual: 0.0009271877079378656
# Time step 209, Time 125400.00 s
# Inflow rate: 0.000000, Outflow rate: 2109.177793
# Net flux (should be close to zero): -2109.177793
# Step 210, Mass Conservation Residual: 0.0009264247747793311
# Time step 210, Time 126000.00 s
# Inflow rate: 0.000000, Outflow rate: 2191.934852
# Net flux (should be close to zero): -2191.934852
# Step 211, Mass Conservation Residual: 0.000924226003242599
# Time step 211, Time 126600.00 s
# Inflow rate: 0.000000, Outflow rate: 2146.890403
# Net flux (should be close to zero): -2146.890403
# Step 212, Mass Conservation Residual: 0.0009045603994432088
# Time step 212, Time 127200.00 s
# Inflow rate: 0.000000, Outflow rate: 1986.522472
# Net flux (should be close to zero): -1986.522472
# Step 213, Mass Conservation Residual: 0.0008710286245013183
# Time step 213, Time 127800.00 s
# Inflow rate: 0.000000, Outflow rate: 1735.613870
# Net flux (should be close to zero): -1735.613870
# Step 214, Mass Conservation Residual: 0.000836986714815736
# Time step 214, Time 128400.00 s
# Inflow rate: 0.000000, Outflow rate: 1411.832110
# Net flux (should be close to zero): -1411.832110
# Step 215, Mass Conservation Residual: 0.0007664133601496717
# Time step 215, Time 129000.00 s
# Inflow rate: 0.000000, Outflow rate: 1017.993191
# Net flux (should be close to zero): -1017.993191
# Step 216, Mass Conservation Residual: 0.0006875579404090334
# Time step 216, Time 129600.00 s
# Inflow rate: 0.000000, Outflow rate: 548.665274
# Net flux (should be close to zero): -548.665274
# Step 217, Mass Conservation Residual: 0.0006338384610314468
# Time step 217, Time 130200.00 s
# Inflow rate: 0.000000, Outflow rate: 0.000000
# Net flux (should be close to zero): -0.000000
# Step 218, Mass Conservation Residual: 0.0006095549518749787
# Time step 218, Time 130800.00 s
# Inflow rate: 624.228904, Outflow rate: 0.000000
# Net flux (should be close to zero): 624.228904
# Step 219, Mass Conservation Residual: 0.0006626657650268922
# Time step 219, Time 131400.00 s
# Inflow rate: 1305.656169, Outflow rate: 0.000000
# Net flux (should be close to zero): 1305.656169
# Step 220, Mass Conservation Residual: 0.00087016774673637
# Time step 220, Time 132000.00 s
# Inflow rate: 2011.258411, Outflow rate: 0.000000
# Net flux (should be close to zero): 2011.258411
# Step 221, Mass Conservation Residual: 0.0011991308656366384
# Time step 221, Time 132600.00 s
# Inflow rate: 2701.628264, Outflow rate: 0.000000
# Net flux (should be close to zero): 2701.628264
# Step 222, Mass Conservation Residual: 0.001599564336182615
# Time step 222, Time 133200.00 s
# Inflow rate: 3346.959276, Outflow rate: 0.000000
# Net flux (should be close to zero): 3346.959276
# Step 223, Mass Conservation Residual: 0.0020704268964726776
# Time step 223, Time 133800.00 s
# Inflow rate: 3954.315156, Outflow rate: 0.000000
# Net flux (should be close to zero): 3954.315156
# Step 224, Mass Conservation Residual: 0.00267143886966762
# Time step 224, Time 134400.00 s
# Inflow rate: 4569.343752, Outflow rate: 0.000000
# Net flux (should be close to zero): 4569.343752
# Step 225, Mass Conservation Residual: 0.0034950732859098427
# Time step 225, Time 135000.00 s
# Inflow rate: 5235.375242, Outflow rate: 21.260301
# Net flux (should be close to zero): 5214.114942
# Step 226, Mass Conservation Residual: 0.00463096313172952
# Time step 226, Time 135600.00 s
# Inflow rate: 5949.574692, Outflow rate: 138.986853
# Net flux (should be close to zero): 5810.587839
# Step 227, Mass Conservation Residual: 0.005886683339027305
# Time step 227, Time 136200.00 s
# Inflow rate: 6534.621134, Outflow rate: 329.493032
# Net flux (should be close to zero): 6205.128101
# Step 228, Mass Conservation Residual: 0.006710052298482333
# Time step 228, Time 136800.00 s
# Inflow rate: 7222.047263, Outflow rate: 929.914624
# Net flux (should be close to zero): 6292.132638
# Step 229, Mass Conservation Residual: 0.006850608857987222
# Time step 229, Time 137400.00 s
# Inflow rate: 7458.169927, Outflow rate: 1364.671235
# Net flux (should be close to zero): 6093.498692
# Step 230, Mass Conservation Residual: 0.006545349964459049
# Time step 230, Time 138000.00 s
# Inflow rate: 7391.572824, Outflow rate: 1695.803005
# Net flux (should be close to zero): 5695.769819
# Step 231, Mass Conservation Residual: 0.006189032938039911
# Time step 231, Time 138600.00 s
# Inflow rate: 7020.835505, Outflow rate: 1862.137981
# Net flux (should be close to zero): 5158.697525
# Step 232, Mass Conservation Residual: 0.006158945394446492
# Time step 232, Time 139200.00 s
# Inflow rate: 6435.446391, Outflow rate: 1955.783857
# Net flux (should be close to zero): 4479.662534
# Step 233, Mass Conservation Residual: 0.006656205227687807
# Time step 233, Time 139800.00 s
# Inflow rate: 5746.339661, Outflow rate: 2106.741910
# Net flux (should be close to zero): 3639.597751
# Step 234, Mass Conservation Residual: 0.007435240944782457
# Time step 234, Time 140400.00 s
# Inflow rate: 5254.612574, Outflow rate: 2562.816388
# Net flux (should be close to zero): 2691.796186
# Step 235, Mass Conservation Residual: 0.00803875168923121
# Time step 235, Time 141000.00 s
# Inflow rate: 5622.043525, Outflow rate: 3884.059184
# Net flux (should be close to zero): 1737.984340
# Step 236, Mass Conservation Residual: 0.008460783045631186
# Time step 236, Time 141600.00 s
# Inflow rate: 6196.699191, Outflow rate: 5359.974883
# Net flux (should be close to zero): 836.724308
# Step 237, Mass Conservation Residual: 0.008818828874089673
# Time step 237, Time 142200.00 s
# Inflow rate: 5770.126153, Outflow rate: 5896.121038
# Net flux (should be close to zero): -125.994885
# Step 238, Mass Conservation Residual: 0.00839930071512149
# Time step 238, Time 142800.00 s
# Inflow rate: 4360.347663, Outflow rate: 5514.683667
# Net flux (should be close to zero): -1154.336004
# Step 239, Mass Conservation Residual: 0.0069233710923596375
# Time step 239, Time 143400.00 s
# Inflow rate: 3797.343360, Outflow rate: 5847.546391
# Net flux (should be close to zero): -2050.203031
# Step 240, Mass Conservation Residual: 0.005455837671674389
# Time step 240, Time 144000.00 s
# Inflow rate: 2883.034466, Outflow rate: 5683.211451
# Net flux (should be close to zero): -2800.176986
# Step 241, Mass Conservation Residual: 0.004750291940091058
# Time step 241, Time 144600.00 s
# Inflow rate: 2192.967197, Outflow rate: 5455.029524
# Net flux (should be close to zero): -3262.062328
# Step 242, Mass Conservation Residual: 0.0043875580476083875
# Time step 242, Time 145200.00 s
# Inflow rate: 1977.011202, Outflow rate: 5453.140555
# Net flux (should be close to zero): -3476.129353
# Step 243, Mass Conservation Residual: 0.003901950796932714
# Time step 243, Time 145800.00 s
# Inflow rate: 1657.482980, Outflow rate: 5251.804970
# Net flux (should be close to zero): -3594.321991
# Step 244, Mass Conservation Residual: 0.00328656451721268
# Time step 244, Time 146400.00 s
# Inflow rate: 1185.477963, Outflow rate: 4845.111030
# Net flux (should be close to zero): -3659.633067
# Step 245, Mass Conservation Residual: 0.0026782219567227
# Time step 245, Time 147000.00 s
# Inflow rate: 692.673944, Outflow rate: 4338.310062
# Net flux (should be close to zero): -3645.636117
# Step 246, Mass Conservation Residual: 0.0021725980335377615
# Time step 246, Time 147600.00 s
# Inflow rate: 260.852508, Outflow rate: 3784.332656
# Net flux (should be close to zero): -3523.480148
# Step 247, Mass Conservation Residual: 0.001797648989933844
# Time step 247, Time 148200.00 s
# Inflow rate: 0.283353, Outflow rate: 3279.439295
# Net flux (should be close to zero): -3279.155941
# Step 248, Mass Conservation Residual: 0.001527914813326884
# Time step 248, Time 148800.00 s
# Inflow rate: 0.000000, Outflow rate: 2913.420624
# Net flux (should be close to zero): -2913.420624
# Step 249, Mass Conservation Residual: 0.0013106087549911087
# Time step 249, Time 149400.00 s
# Inflow rate: 0.000000, Outflow rate: 2449.219186
# Net flux (should be close to zero): -2449.219186
# Step 250, Mass Conservation Residual: 0.0011097533728339005
# Time step 250, Time 150000.00 s
# Inflow rate: 0.000000, Outflow rate: 1909.494087
# Net flux (should be close to zero): -1909.494087
# Step 251, Mass Conservation Residual: 0.0009141027764141007
# Time step 251, Time 150600.00 s
# Inflow rate: 0.000000, Outflow rate: 1310.351451
# Net flux (should be close to zero): -1310.351451
# Step 252, Mass Conservation Residual: 0.0007284525333318263
# Time step 252, Time 151200.00 s
# Inflow rate: 0.000000, Outflow rate: 667.285130
# Net flux (should be close to zero): -667.285130
# Step 253, Mass Conservation Residual: 0.0005698649867268852
# Time step 253, Time 151800.00 s
# Inflow rate: 0.000000, Outflow rate: 0.000000
# ...
# Net flux (should be close to zero): 804.645552
# Step 925, Mass Conservation Residual: 0.0011712809618537358
# Time step 925, Time 555000.00 s
# Inflow rate: 199.756229, Outflow rate: 303.059554
# Net flux (should be close to zero): -103.303325
# Step 926, Mass Conservation Residual: 0.0011327015981188104
# Time step 926, Time 555600.00 s
# Inflow rate: 0.000000, Outflow rate: 985.420293
# Net flux (should be close to zero): -985.420293
# Step 927, Mass Conservation Residual: 0.0011057980697378599
# Time step 927, Time 556200.00 s
# Inflow rate: 0.000000, Outflow rate: 1706.268373
# Net flux (should be close to zero): -1706.268373
# Step 928, Mass Conservation Residual: 0.0010821397024883069
# Time step 928, Time 556800.00 s
# Inflow rate: 0.000000, Outflow rate: 2205.975618
# Net flux (should be close to zero): -2205.975618
# Step 929, Mass Conservation Residual: 0.001074183241051181
# Time step 929, Time 557400.00 s
# Inflow rate: 0.000000, Outflow rate: 2474.887128
# Net flux (should be close to zero): -2474.887128
# Step 930, Mass Conservation Residual: 0.0010707717602562153
# Time step 930, Time 558000.00 s
# Inflow rate: 0.000000, Outflow rate: 2576.946353
# Net flux (should be close to zero): -2576.946353
# Step 931, Mass Conservation Residual: 0.001054038640769861
# Time step 931, Time 558600.00 s
# Inflow rate: 0.000000, Outflow rate: 2545.999322
# Net flux (should be close to zero): -2545.999322
# Step 932, Mass Conservation Residual: 0.0010354332794686217
# Time step 932, Time 559200.00 s
# Inflow rate: 0.000000, Outflow rate: 2379.341206
# Net flux (should be close to zero): -2379.341206
# Step 933, Mass Conservation Residual: 0.0010015245506374522
# Time step 933, Time 559800.00 s
# Inflow rate: 0.000000, Outflow rate: 2083.806182
# Net flux (should be close to zero): -2083.806182
# Step 934, Mass Conservation Residual: 0.0009405768579661012
# Time step 934, Time 560400.00 s
# Inflow rate: 0.000000, Outflow rate: 1685.295708
# Net flux (should be close to zero): -1685.295708
# Step 935, Mass Conservation Residual: 0.0008854359221349291
# Time step 935, Time 561000.00 s
# Inflow rate: 0.000000, Outflow rate: 1204.727565
# Net flux (should be close to zero): -1204.727565
# Step 936, Mass Conservation Residual: 0.0007950951424846938
# Time step 936, Time 561600.00 s
# Inflow rate: 0.000000, Outflow rate: 645.674167
# Net flux (should be close to zero): -645.674167
# Step 937, Mass Conservation Residual: 0.0007073846536325434
# Time step 937, Time 562200.00 s
# Inflow rate: 0.000000, Outflow rate: 0.000000
# Net flux (should be close to zero): -0.000000
# Step 938, Mass Conservation Residual: 0.0006958465154220067
# Time step 938, Time 562800.00 s
# Inflow rate: 736.847612, Outflow rate: 0.000000
# Net flux (should be close to zero): 736.847612
# Step 939, Mass Conservation Residual: 0.0007910611530090792
# Time step 939, Time 563400.00 s
# Inflow rate: 1550.239221, Outflow rate: 0.000000
# Net flux (should be close to zero): 1550.239221
# Step 940, Mass Conservation Residual: 0.0010389712936241505
# Time step 940, Time 564000.00 s
# Inflow rate: 2403.337847, Outflow rate: 0.000000
# Net flux (should be close to zero): 2403.337847
# Step 941, Mass Conservation Residual: 0.0014649040883315198
# Time step 941, Time 564600.00 s
# Inflow rate: 3244.083302, Outflow rate: 0.000000
# Net flux (should be close to zero): 3244.083302
# Step 942, Mass Conservation Residual: 0.002004126626777867
# Time step 942, Time 565200.00 s
# Inflow rate: 4020.356851, Outflow rate: 0.000000
# Net flux (should be close to zero): 4020.356851
# Step 943, Mass Conservation Residual: 0.0026353175609261396
# Time step 943, Time 565800.00 s
# Inflow rate: 4722.403411, Outflow rate: 0.000000
# Net flux (should be close to zero): 4722.403411
# Step 944, Mass Conservation Residual: 0.0034414562195221143
# Time step 944, Time 566400.00 s
# Inflow rate: 5416.554359, Outflow rate: 0.000000
# Net flux (should be close to zero): 5416.554359
# Step 945, Mass Conservation Residual: 0.004564661913595878
# Time step 945, Time 567000.00 s
# Inflow rate: 6252.255190, Outflow rate: 86.654261
# Net flux (should be close to zero): 6165.600928
# Step 946, Mass Conservation Residual: 0.006033575212428496
# Time step 946, Time 567600.00 s
# Inflow rate: 7078.195628, Outflow rate: 192.891065
# Net flux (should be close to zero): 6885.304563
# Step 947, Mass Conservation Residual: 0.00741013090167776
# Time step 947, Time 568200.00 s
# Inflow rate: 8165.791289, Outflow rate: 817.550420
# Net flux (should be close to zero): 7348.240870
# Step 948, Mass Conservation Residual: 0.008022086385362599
# Time step 948, Time 568800.00 s
# Inflow rate: 8767.160432, Outflow rate: 1363.372793
# Net flux (should be close to zero): 7403.787639
# Step 949, Mass Conservation Residual: 0.007831432950880703
# Time step 949, Time 569400.00 s
# Inflow rate: 8947.523581, Outflow rate: 1838.024758
# Net flux (should be close to zero): 7109.498823
# Step 950, Mass Conservation Residual: 0.007421032562823022
# Time step 950, Time 570000.00 s
# Inflow rate: 8677.600828, Outflow rate: 2046.382071
# Net flux (should be close to zero): 6631.218757
# Step 951, Mass Conservation Residual: 0.007601498023061117
# Time step 951, Time 570600.00 s
# Inflow rate: 8315.105214, Outflow rate: 2256.983452
# Net flux (should be close to zero): 6058.121762
# Step 952, Mass Conservation Residual: 0.00892797606076562
# Time step 952, Time 571200.00 s
# Inflow rate: 7935.223203, Outflow rate: 2564.647070
# Net flux (should be close to zero): 5370.576133
# Step 953, Mass Conservation Residual: 0.011037057935470267
# Time step 953, Time 571800.00 s
# Inflow rate: 8336.501088, Outflow rate: 3673.317582
# Net flux (should be close to zero): 4663.183506
# Step 954, Mass Conservation Residual: 0.013153573090141127
# Time step 954, Time 572400.00 s
# Inflow rate: 10545.707984, Outflow rate: 6633.692398
# Net flux (should be close to zero): 3912.015586
# Step 955, Mass Conservation Residual: 0.013120017832560426
# Time step 955, Time 573000.00 s
# Inflow rate: 8624.311912, Outflow rate: 6498.736423
# Net flux (should be close to zero): 2125.575489
# Step 956, Mass Conservation Residual: 0.011084885734661893
# Time step 956, Time 573600.00 s
# Inflow rate: 7911.953673, Outflow rate: 7249.816692
# Net flux (should be close to zero): 662.136981
# Step 957, Mass Conservation Residual: 0.009128059849551954
# Time step 957, Time 574200.00 s
# Inflow rate: 6946.846089, Outflow rate: 7523.429498
# Net flux (should be close to zero): -576.583409
# Step 958, Mass Conservation Residual: 0.00858977479423549
# Time step 958, Time 574800.00 s
# Inflow rate: 5592.639452, Outflow rate: 7225.455614
# Net flux (should be close to zero): -1632.816162
# Step 959, Mass Conservation Residual: 0.008150553824549423
# Time step 959, Time 575400.00 s
# Inflow rate: 4855.223491, Outflow rate: 7320.146458
# Net flux (should be close to zero): -2464.922967
# Step 960, Mass Conservation Residual: 0.007124580878237242
# Time step 960, Time 576000.00 s
# Inflow rate: 4051.004072, Outflow rate: 7253.274888
# Net flux (should be close to zero): -3202.270816
# Step 961, Mass Conservation Residual: 0.005910462874817862
# Time step 961, Time 576600.00 s
# Inflow rate: 3104.245633, Outflow rate: 6942.063556
# Net flux (should be close to zero): -3837.817922
# Step 962, Mass Conservation Residual: 0.004863419799810052
# Time step 962, Time 577200.00 s
# Inflow rate: 2035.821278, Outflow rate: 6339.965273
# Net flux (should be close to zero): -4304.143995
# Step 963, Mass Conservation Residual: 0.004059350131839039
# Time step 963, Time 577800.00 s
# Inflow rate: 1121.223221, Outflow rate: 5681.487805
# Net flux (should be close to zero): -4560.264585
# Step 964, Mass Conservation Residual: 0.0034156746434279915
# Time step 964, Time 578400.00 s
# Inflow rate: 527.350325, Outflow rate: 5131.630091
# Net flux (should be close to zero): -4604.279765
# Step 965, Mass Conservation Residual: 0.0028567913018443815
# Time step 965, Time 579000.00 s
# Inflow rate: 165.684774, Outflow rate: 4633.336558
# Net flux (should be close to zero): -4467.651784
# Step 966, Mass Conservation Residual: 0.002384505613327213
# Time step 966, Time 579600.00 s
# Inflow rate: 0.000000, Outflow rate: 4189.836291
# Net flux (should be close to zero): -4189.836291
# Step 967, Mass Conservation Residual: 0.0020115983189520317
# Time step 967, Time 580200.00 s
# Inflow rate: 0.000000, Outflow rate: 3798.384457
# Net flux (should be close to zero): -3798.384457
# Step 968, Mass Conservation Residual: 0.001715415513439527
# Time step 968, Time 580800.00 s
# Inflow rate: 0.000000, Outflow rate: 3318.329198
# Net flux (should be close to zero): -3318.329198
# Step 969, Mass Conservation Residual: 0.0014622932702902077
# Time step 969, Time 581400.00 s
# Inflow rate: 0.000000, Outflow rate: 2765.094513
# Net flux (should be close to zero): -2765.094513
# Step 970, Mass Conservation Residual: 0.0012297968088884328
# Time step 970, Time 582000.00 s
# Inflow rate: 0.000000, Outflow rate: 2146.443617
# Net flux (should be close to zero): -2146.443617
# Step 971, Mass Conservation Residual: 0.0010093842268740255
# Time step 971, Time 582600.00 s
# Inflow rate: 0.000000, Outflow rate: 1469.598674
# Net flux (should be close to zero): -1469.598674
# Step 972, Mass Conservation Residual: 0.0008041094465348189
# Time step 972, Time 583200.00 s
# Inflow rate: 0.000000, Outflow rate: 747.137314
# Net flux (should be close to zero): -747.137314
# Step 973, Mass Conservation Residual: 0.0006300967322216536
# Time step 973, Time 583800.00 s
# Inflow rate: 0.000000, Outflow rate: 0.000000
# Net flux (should be close to zero): -0.000000
# Step 974, Mass Conservation Residual: 0.0005198852970615588
# Time step 974, Time 584400.00 s
# Inflow rate: 746.793828, Outflow rate: 0.000000
# Net flux (should be close to zero): 746.793828
# Step 975, Mass Conservation Residual: 0.0005093120164820356
# Time step 975, Time 585000.00 s
# Inflow rate: 1477.010175, Outflow rate: 0.000000
# Net flux (should be close to zero): 1477.010175
# Step 976, Mass Conservation Residual: 0.0005938165484293061
# Time step 976, Time 585600.00 s
# Inflow rate: 2185.730159, Outflow rate: 0.000000
# Net flux (should be close to zero): 2185.730159
# Step 977, Mass Conservation Residual: 0.0007323878770644338
# Time step 977, Time 586200.00 s
# Inflow rate: 2870.287869, Outflow rate: 0.000000
# Net flux (should be close to zero): 2870.287869
# Step 978, Mass Conservation Residual: 0.000892157302827016
# Time step 978, Time 586800.00 s
# Inflow rate: 3524.716387, Outflow rate: 0.000000
# Net flux (should be close to zero): 3524.716387
# Step 979, Mass Conservation Residual: 0.001055768297011085
# Time step 979, Time 587400.00 s
# Inflow rate: 4139.381728, Outflow rate: 0.000000
# Net flux (should be close to zero): 4139.381728
# Step 980, Mass Conservation Residual: 0.0012139106853616328
# Time step 980, Time 588000.00 s
# Inflow rate: 4702.422263, Outflow rate: 0.000000
# Net flux (should be close to zero): 4702.422263
# Step 981, Mass Conservation Residual: 0.0013608271598838549
# Time step 981, Time 588600.00 s
# Inflow rate: 5201.171335, Outflow rate: 0.000000
# Net flux (should be close to zero): 5201.171335
# Step 982, Mass Conservation Residual: 0.001492501362250206
# Time step 982, Time 589200.00 s
# Inflow rate: 5623.161632, Outflow rate: 0.000000
# Net flux (should be close to zero): 5623.161632
# Step 983, Mass Conservation Residual: 0.0016059536795656685
# Time step 983, Time 589800.00 s
# Inflow rate: 5956.798614, Outflow rate: 0.000000
# Net flux (should be close to zero): 5956.798614
# Step 984, Mass Conservation Residual: 0.001698956829948477
# Time step 984, Time 590400.00 s
# Inflow rate: 6191.848714, Outflow rate: 0.000000
# Net flux (should be close to zero): 6191.848714
# Step 985, Mass Conservation Residual: 0.0017699210128560563
# Time step 985, Time 591000.00 s
# Inflow rate: 6319.839700, Outflow rate: 0.000000
# Net flux (should be close to zero): 6319.839700
# Step 986, Mass Conservation Residual: 0.0018178551997101045
# Time step 986, Time 591600.00 s
# Inflow rate: 6334.422418, Outflow rate: 0.000000
# Net flux (should be close to zero): 6334.422418
# Step 987, Mass Conservation Residual: 0.0018423623161178224
# Time step 987, Time 592200.00 s
# Inflow rate: 6231.712299, Outflow rate: 0.000000
# Net flux (should be close to zero): 6231.712299
# Step 988, Mass Conservation Residual: 0.0018436432917292437
# Time step 988, Time 592800.00 s
# Inflow rate: 6010.608779, Outflow rate: 0.000000
# Net flux (should be close to zero): 6010.608779
# Step 989, Mass Conservation Residual: 0.001822495058539891
# Time step 989, Time 593400.00 s
# Inflow rate: 5673.071190, Outflow rate: 0.000000
# Net flux (should be close to zero): 5673.071190
# Step 990, Mass Conservation Residual: 0.0017802963722621942
# Time step 990, Time 594000.00 s
# Inflow rate: 5224.303990, Outflow rate: 0.000000
# Net flux (should be close to zero): 5224.303990
# Step 991, Mass Conservation Residual: 0.0017189828645036624
# Time step 991, Time 594600.00 s
# Inflow rate: 4672.764759, Outflow rate: 0.000000
# Net flux (should be close to zero): 4672.764759
# Step 992, Mass Conservation Residual: 0.0016410355507812098
# Time step 992, Time 595200.00 s
# Inflow rate: 4029.851854, Outflow rate: 0.000000
# Net flux (should be close to zero): 4029.851854
# Step 993, Mass Conservation Residual: 0.0015495398646259498
# Time step 993, Time 595800.00 s
# Inflow rate: 3309.077344, Outflow rate: 0.000000
# Net flux (should be close to zero): 3309.077344
# Step 994, Mass Conservation Residual: 0.0014484312488877223
# Time step 994, Time 596400.00 s
# Inflow rate: 2524.467651, Outflow rate: 0.000000
# Net flux (should be close to zero): 2524.467651
# Step 995, Mass Conservation Residual: 0.0013432107994327518
# Time step 995, Time 597000.00 s
# Inflow rate: 1687.727346, Outflow rate: 0.000000
# Net flux (should be close to zero): 1687.727346
# Step 996, Mass Conservation Residual: 0.0012435600682082744
# Time step 996, Time 597600.00 s
# Inflow rate: 904.015920, Outflow rate: 99.358336
# Net flux (should be close to zero): 804.657584
# Step 997, Mass Conservation Residual: 0.0011712868178354909
# Time step 997, Time 598200.00 s
# Inflow rate: 199.762725, Outflow rate: 303.059566
# Net flux (should be close to zero): -103.296841
# Step 998, Mass Conservation Residual: 0.001132707365701682
# Time step 998, Time 598800.00 s
# Inflow rate: 0.000000, Outflow rate: 985.419740
# Net flux (should be close to zero): -985.419740
# Step 999, Mass Conservation Residual: 0.0011058036660157927
# Time step 999, Time 599400.00 s
# Inflow rate: 0.000000, Outflow rate: 1706.272980
# Net flux (should be close to zero): -1706.272980
# Step 1000, Mass Conservation Residual: 0.0010821447115896279
# Time step 1000, Time 600000.00 s
# Inflow rate: 0.000000, Outflow rate: 2205.984682
# Net flux (should be close to zero): -2205.984682
# Step 1001, Mass Conservation Residual: 0.0010741877400371298
# Time step 1001, Time 600600.00 s
# Inflow rate: 0.000000, Outflow rate: 2474.898521
# Net flux (should be close to zero): -2474.898521
# Step 1002, Mass Conservation Residual: 0.001070775936764329
# Time step 1002, Time 601200.00 s
# Inflow rate: 0.000000, Outflow rate: 2576.958095
# Net flux (should be close to zero): -2576.958095
# Step 1003, Mass Conservation Residual: 0.0010540429552256007
# Time step 1003, Time 601800.00 s
# Inflow rate: 0.000000, Outflow rate: 2546.011120
# Net flux (should be close to zero): -2546.011120
# Step 1004, Mass Conservation Residual: 0.0010354366970644162
# Time step 1004, Time 602400.00 s
# Inflow rate: 0.000000, Outflow rate: 2379.352938
# Net flux (should be close to zero): -2379.352938
# Step 1005, Mass Conservation Residual: 0.001001528708262098
# Time step 1005, Time 603000.00 s
# Inflow rate: 0.000000, Outflow rate: 2083.816955
# Net flux (should be close to zero): -2083.816955
# Step 1006, Mass Conservation Residual: 0.0009405800628015427
# Time step 1006, Time 603600.00 s
# Inflow rate: 0.000000, Outflow rate: 1685.304389
# Net flux (should be close to zero): -1685.304389
# Step 1007, Mass Conservation Residual: 0.0008854389226703016
# Time step 1007, Time 604200.00 s
# Inflow rate: 0.000000, Outflow rate: 1204.733526
# Net flux (should be close to zero): -1204.733526
# Step 1008, Mass Conservation Residual: 0.000795098886985787
# Time step 1008, Time 604800.00 s
# Inflow rate: 0.000000, Outflow rate: 645.677228
# Net flux (should be close to zero): -645.677228

# %%
# # plotting the station data 
# import matplotlib.pyplot as plt

# # Plot time series for each station
# for coord in station_coords:
#     plt.figure(figsize=(10, 6))

#     # Plot surface elevation
#     plt.subplot(3, 1, 1)
#     plt.plot(time_series_data[coord]["time"], time_series_data[coord]["h"], label="Surface Elevation (h)")
#     plt.title(f"Station at x = {coord} m")
#     plt.xlabel("Time (s)")
#     plt.ylabel("Elevation (m)")
#     plt.grid()
#     plt.legend()

#     # Plot velocity in x-direction
#     plt.subplot(3, 1, 2)
#     plt.plot(time_series_data[coord]["time"], time_series_data[coord]["ux"], label="Velocity (ux)", color="orange")
#     plt.xlabel("Time (s)")
#     plt.ylabel("Velocity (m/s)")
#     plt.grid()
#     plt.legend()

#     # Plot velocity in y-direction
#     plt.subplot(3, 1, 3)
#     plt.plot(time_series_data[coord]["time"], time_series_data[coord]["uy"], label="Velocity (uy)", color="green")
#     plt.xlabel("Time (s)")
#     plt.ylabel("Velocity (m/s)")
#     plt.grid()
#     plt.legend()

#     plt.tight_layout()
#     plt.savefig(f"station_{coord}_timeseries.png")  # Save plot as image
#     plt.show()

# %%
# Importing libraries
import matplotlib.pyplot as plt
import numpy as np  # If you need it for generating example ticks

# Plot time series for each station
for coord in station_coords:
    plt.figure(figsize=(10, 6))

    # Plot surface elevation
    plt.subplot(3, 1, 1)
    plt.plot(time_series_data[coord]["time"], time_series_data[coord]["h"], label="Surface Elevation (h)")
    plt.title(f"Station at x = {coord} m")
    plt.xlabel("Time (s)")
    plt.ylabel("Elevation (m)")

    # Set y-ticks at unit intervals and enable grid
    y_min, y_max = plt.ylim()  # Get current y-limits
    plt.yticks(np.arange(np.floor(y_min) , np.ceil(y_max) + 0.5, 0.5))  # Set y-ticks at unit intervals
    plt.grid(axis='y')  # Add grid lines for y-axis only
    plt.legend()

    # Plot velocity in x-direction
    plt.subplot(3, 1, 2)
    plt.plot(time_series_data[coord]["time"], time_series_data[coord]["ux"], label="Velocity (ux)", color="orange")
    plt.xlabel("Time (s)")
    plt.ylabel("Velocity (m/s)")

    # Set y-ticks at unit intervals and enable grid
    y_min, y_max = plt.ylim()  # Get current y-limits
    plt.yticks(np.arange(np.floor(y_min) + 0.4, np.ceil(y_max) +0.1, 0.2))  # Set y-ticks at unit intervals
    plt.grid(axis='y')  # Add grid lines for y-axis only
    plt.legend()

    # Plot velocity in y-direction
    plt.subplot(3, 1, 3)
    plt.plot(time_series_data[coord]["time"], time_series_data[coord]["uy"], label="Velocity (uy)", color="green")
    plt.xlabel("Time (s)")
    plt.ylabel("Velocity (m/s)")

    # Set y-ticks at unit intervals and enable grid
    y_min, y_max = plt.ylim()  # Get current y-limits
    plt.yticks(np.arange(np.floor(y_min) +0.7, np.ceil(y_max) - 0.8, 0.1))  # Set y-ticks at unit intervals
    plt.grid(axis='y')  # Add grid lines for y-axis only
    plt.legend()

    plt.tight_layout()
    plt.savefig(f"station_{coord}_timeseries.png")  # Save plot as image
    plt.show()

# %%
# np.arange(np.floor(y_min) + 2, np.ceil(y_max) + 0.5, 0.5)
# y_min
# Out:
# np.float64(-0.05500000000000001)

# %%
# !pip install imageio
# !pip install imageio[ffmpeg]
import imageio.v2 as imageio

# Collect all frame files
frame_files = sorted([f"frames/frame_{i:04d}.png" for i in range(1009)])

# Write video file
with imageio.get_writer("simulation_wetdry_ramp_weakform_as_swemnics_cg.mp4", fps=8) as writer:
    for frame_file in frame_files:
        image = imageio.imread(frame_file)
        writer.append_data(image)
